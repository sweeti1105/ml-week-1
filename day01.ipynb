# %% [markdown]
# <a href="https://colab.research.google.com/github/sweeti1105/ml-week-1/blob/day1/day01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# About Me Program
name = input("Name: ")
age = input("Age: ")
location = input("Location: ")
interest = input("Interest: ")

print(f"\nHi! I'm {name}, {age} years old from {location}. I love {interest}!")
# Out:
# Name: sweeti chouhan
# Age: 18
# Location: Bhopal
# Interest: coding
#
# Hi! I'm sweeti chouhan, 18 years old from Bhopal. I love coding!

# %%
# Grocery Bill Calculator with 18% GST
items = int(input("Number of items: "))
total = 0

for i in range(items):
    price = float(input(f"Price of item {i+1}: ₹"))
    qty = int(input(f"Quantity of item {i+1}: "))
    total += price * qty

gst = total * 0.18
print(f"\nSubtotal: ₹{total:.2f}")
print(f"GST (18%): ₹{gst:.2f}")
print(f"Total Bill: ₹{total + gst:.2f}")
# Out:
# Number of items: 1
# Price of item 1: ₹500
# Quantity of item 1: 2
#
# Subtotal: ₹1000.00
# GST (18%): ₹180.00
# Total Bill: ₹1180.00

# %%
# Grading System
marks = float(input("Enter marks (0-100): "))

if marks >= 90:
    grade = "A"
elif marks >= 75:
    grade = "B"
elif marks >= 60:
    grade = "C"
elif marks >= 40:
    grade = "D"
else:
    grade = "Fail"

print(f"Grade: {grade}")
# Out:
# Enter marks (0-100): 70
# Grade: C

# %%
# Temperature Tracker
temperatures = []

print("Enter temperatures for 5 days:")
for day in range(1, 6):
    temp = float(input(f"Day {day} temperature: "))
    temperatures.append(temp)

average = sum(temperatures) / len(temperatures)
print(f"\nTemperatures: {temperatures}")
print(f"Average temperature: {average:.1f}°C")2
# Out:
# Enter temperatures for 5 days:
# Day 1 temperature: 23
# Day 2 temperature: 24
# Day 3 temperature: 6
# Day 4 temperature: 43
# Day 5 temperature: 28
#
# Temperatures: [23.0, 24.0, 6.0, 43.0, 28.0]
# Average temperature: 24.8°C

# %%
# Number Guessing Game (5 attempts)
import random

secret = random.randint(1, 100)
attempts = 5

print("Guess the secret number (1-100)! You have 5 attempts.")

for attempt in range(1, attempts + 1):
    while True:
        try:
            guess = int(input(f"Attempt {attempt}/{attempts}: "))
            if 1 <= guess <= 100:
                break
            print("Please enter a number between 1-100!")
        except ValueError:
            print("Invalid input! Numbers only.")
            continue  # Skip to next iteration if input is invalid

    if guess == secret:
        print(f"🎉 Correct! The number was {secret}.")
        break  # Exit early if correct
    elif guess < secret:
        print("Too low! ↑")
    else:
        print("Too high! ↓")
else:  # This runs if loop completes without breaking
    print(f"❌ Game over! The number was {secret}.")57
# Out:
# Guess the secret number (1-100)! You have 5 attempts.
# Attempt 1/5: 50
# Too low! ↑
# Attempt 2/5: 6
# Too low! ↑
# Attempt 3/5: 76
# Too high! ↓
# Attempt 4/5: 87
# Too high! ↓
# Attempt 5/5: 36
# Too low! ↑
# ❌ Game over! The number was 66.
